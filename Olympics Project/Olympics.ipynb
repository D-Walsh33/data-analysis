# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
athletes = pd.read_csv('./data/Olympic_Athlete_Biography.csv')
athletes
# Out:
#         athlete_id                name     sex               born  height  \
# 0            65649       Ivanka Bonova  Female       4 April 1949   166.0
# 1           112510   Nataliya Uryadova  Female      15 March 1977   184.0
# 2           114973  Essa Ismail Rashed    Male   14 December 1986   165.0
# 3            30359         Péter Boros    Male    12 January 1908     NaN
# 4            50557      Rudolf Piowatý    Male      28 April 1900     NaN
# ...            ...                 ...     ...                ...     ...
# 155856       23748         Todd Makler    Male     8 January 1946   183.0
# 155857       58581        Géza Hollósi    Male         2 May 1938   175.0
# 155858       30387  József Keresztessy    Male  19 September 1885     NaN
# 155859       69900    Alexander Thieme    Male    13 January 1954   187.0
# 155860       74003         Sunday Bada    Male       22 June 1969   188.0
#
#        weight              country country_noc  \
# ...

# %%
athlete_events = pd.read_csv('./data/Olympic_Athlete_Event_Details.csv')
athlete_events[(athlete_events['country_noc'] == 'USA') & (athlete_events['medal'] == 'Gold')]
# Out:
#                      edition  edition_id country_noc          sport  \
# 293116  1896 Summer Olympics           1         USA      Athletics
# 293121  1896 Summer Olympics           1         USA      Athletics
# 293126  1896 Summer Olympics           1         USA      Athletics
# 293131  1896 Summer Olympics           1         USA      Athletics
# 293135  1896 Summer Olympics           1         USA      Athletics
# ...                      ...         ...         ...            ...
# 316777  2022 Winter Olympics          62         USA   Snowboarding
# 316785  2022 Winter Olympics          62         USA   Snowboarding
# 316786  2022 Winter Olympics          62         USA   Snowboarding
# 316804  2022 Winter Olympics          62         USA  Speed Skating
# 316814  2022 Winter Olympics          62         USA      Bobsleigh
#
#                           event  result_id             athlete  athlete_id  \
# ...

# %%
# look at a sport and see their medalists heights and weights. check height and weight over time good Idea! others?
