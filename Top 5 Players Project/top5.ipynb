# %%
# Import needed libraries:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/top5-players.csv')
df
sns.scatterplot(data=df, x='Starts', y='Age')
# Out:
# <Axes: xlabel='Starts', ylabel='Age'>
